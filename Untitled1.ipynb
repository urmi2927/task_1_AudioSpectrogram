# %%
! pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\user\anaconda3\lib\site-packages (0.9.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from librosa) (20.9)
# Requirement already satisfied: numba>=0.45.1 in c:\users\user\anaconda3\lib\site-packages (from librosa) (0.53.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\user\anaconda3\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\user\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\user\anaconda3\lib\site-packages (from librosa) (0.24.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\user\anaconda3\lib\site-packages (from librosa) (1.20.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from librosa) (1.6.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\user\anaconda3\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\user\anaconda3\lib\site-packages (from librosa) (0.4.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\user\anaconda3\lib\site-packages (from librosa) (5.0.6)
# Requirement already satisfied: joblib>=0.14 in c:\users\user\anaconda3\lib\site-packages (from librosa) (1.0.1)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (52.0.0.post20210125)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\user\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.36.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\user\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)

# %%
! pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (1.6.2)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\user\anaconda3\lib\site-packages (from scipy) (1.20.1)

# %%
# for data transformation
import numpy as np
# for visualizing the data
import matplotlib.pyplot as plt
# for opening the media file
import scipy.io.wavfile as wavfile

Fs, aud = wavfile.read('data.wav')
# select left channel only
aud = aud[:,0]
# trim the first 125 seconds
first = aud[:int(Fs*125)]

powerSpectrum, frequenciesFound, time, imageAxis = plt.specgram(first, Fs=Fs)
plt.show()
# Out:
# <ipython-input-15-974403d0e76c>:8: WavFileWarning: Reached EOF prematurely; finished at 285112364 bytes, expected 285112372 bytes from header.
#   Fs, aud = wavfile.read('data.wav')
